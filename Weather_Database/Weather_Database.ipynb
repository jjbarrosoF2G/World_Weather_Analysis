# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.b
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobyo
# Processing Record 2 of Set 1 | naze
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | ducheng
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | orocue
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | banmo
# City not found. Skipping...
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | buala
# Processing Record 18 of Set 1 | bar harbor
# Processing Record 19 of Set 1 | fukue
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | bucerias
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | westport
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | yatou
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | vila franca do campo
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | sovetskiy
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | antalaha
# Processing Record 36 of Set 1 | port lincoln
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | urulga
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | saint-joseph
# Processing Record 42 of Set 1 | krasnoselkup
# Processing Record 43 of Set 1 | varniai
# Processing Record 44 of Set 1 | yumen
# Processing Record 45 of Set 1 | buncrana
# Processing Record 46 of Set 1 | hay river
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | mount isa
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | vila
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | harper
# Processing Record 3 of Set 2 | sibolga
# Processing Record 4 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 2 | zlotoryja
# Processing Record 6 of Set 2 | cooma
# Processing Record 7 of Set 2 | padang
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | uray
# Processing Record 13 of Set 2 | maple creek
# Processing Record 14 of Set 2 | akyab
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | aasiaat
# Processing Record 17 of Set 2 | halifax
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | butason
# City not found. Skipping...
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | sakakah
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | hauterive
# Processing Record 24 of Set 2 | santa maria
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | kopavogur
# Processing Record 27 of Set 2 | vlore
# Processing Record 28 of Set 2 | tiznit
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | omboue
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | kodarma
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | jaque
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | kununurra
# Processing Record 42 of Set 2 | cabedelo
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | englewood
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | aquiraz
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | bathsheba
# Processing Record 50 of Set 2 | angoram
# Processing Record 1 of Set 3 | rodrigues alves
# Processing Record 2 of Set 3 | yulara
# Processing Record 3 of Set 3 | dunedin
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | bolobo
# Processing Record 6 of Set 3 | marzuq
# Processing Record 7 of Set 3 | howard springs
# Processing Record 8 of Set 3 | harrisonville
# Processing Record 9 of Set 3 | homer
# Processing Record 10 of Set 3 | san matias
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | morondava
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | maldonado
# Processing Record 17 of Set 3 | union
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | zuya
# Processing Record 22 of Set 3 | udimskiy
# Processing Record 23 of Set 3 | storslett
# Processing Record 24 of Set 3 | galveston
# Processing Record 25 of Set 3 | panguna
# Processing Record 26 of Set 3 | krizevci
# Processing Record 27 of Set 3 | asosa
# Processing Record 28 of Set 3 | candido mendes
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | kawalu
# Processing Record 31 of Set 3 | chicama
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | luanda
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | new glasgow
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | visby
# Processing Record 39 of Set 3 | isangel
# Processing Record 40 of Set 3 | lucapa
# Processing Record 41 of Set 3 | san francisco
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | datong
# Processing Record 45 of Set 3 | mill valley
# Processing Record 46 of Set 3 | pauini
# Processing Record 47 of Set 3 | santa lucia
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | tabou
# Processing Record 50 of Set 3 | woodland
# Processing Record 1 of Set 4 | poum
# Processing Record 2 of Set 4 | burica
# City not found. Skipping...
# Processing Record 3 of Set 4 | alice
# Processing Record 4 of Set 4 | neiafu
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | bantry
# Processing Record 8 of Set 4 | vorukh
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | gopalpur
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | namibe
# Processing Record 14 of Set 4 | oksfjord
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | riyadh
# Processing Record 18 of Set 4 | touros
# Processing Record 19 of Set 4 | carman
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | ozernovskiy
# Processing Record 24 of Set 4 | nantucket
# Processing Record 25 of Set 4 | rawson
# Processing Record 26 of Set 4 | altamont
# Processing Record 27 of Set 4 | aksu
# Processing Record 28 of Set 4 | anchorage
# Processing Record 29 of Set 4 | green valley
# Processing Record 30 of Set 4 | progress
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | dahra
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | tuktoyaktuk
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | chanika
# Processing Record 38 of Set 4 | valladolid
# Processing Record 39 of Set 4 | aksha
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | kano
# Processing Record 42 of Set 4 | egvekinot
# Processing Record 43 of Set 4 | nuuk
# Processing Record 44 of Set 4 | chenzhou
# Processing Record 45 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | college
# Processing Record 48 of Set 4 | mombasa
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | harboore
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | ustye
# Processing Record 3 of Set 5 | kieta
# Processing Record 4 of Set 5 | saint-prosper
# Processing Record 5 of Set 5 | vangaindrano
# Processing Record 6 of Set 5 | saint-pierre
# Processing Record 7 of Set 5 | kamenka
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | yilan
# Processing Record 10 of Set 5 | kemijarvi
# Processing Record 11 of Set 5 | aleksandrov gay
# Processing Record 12 of Set 5 | acapulco
# Processing Record 13 of Set 5 | fortuna
# Processing Record 14 of Set 5 | dubbo
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | mojo
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | killam
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | magadan
# Processing Record 23 of Set 5 | sobolevo
# Processing Record 24 of Set 5 | hofn
# Processing Record 25 of Set 5 | sola
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | panalingaan
# Processing Record 29 of Set 5 | sur
# Processing Record 30 of Set 5 | palmas
# Processing Record 31 of Set 5 | haines junction
# Processing Record 32 of Set 5 | warangal
# Processing Record 33 of Set 5 | barrow
# Processing Record 34 of Set 5 | kumluca
# Processing Record 35 of Set 5 | dong hoi
# Processing Record 36 of Set 5 | huoqiu
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | green river
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | iranshahr
# Processing Record 42 of Set 5 | anse-bertrand
# Processing Record 43 of Set 5 | dhidhdhoo
# Processing Record 44 of Set 5 | prachuap khiri khan
# Processing Record 45 of Set 5 | dumas
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | mao
# Processing Record 48 of Set 5 | rehoboth
# Processing Record 49 of Set 5 | port moresby
# Processing Record 50 of Set 5 | houma
# Processing Record 1 of Set 6 | pevek
# Processing Record 2 of Set 6 | mattru
# Processing Record 3 of Set 6 | guspini
# Processing Record 4 of Set 6 | eyl
# Processing Record 5 of Set 6 | hasaki
# Processing Record 6 of Set 6 | kristiinankaupunki
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | cerrito
# Processing Record 9 of Set 6 | pundaguitan
# Processing Record 10 of Set 6 | upernavik
# Processing Record 11 of Set 6 | lagoa
# Processing Record 12 of Set 6 | lieksa
# Processing Record 13 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 6 | ilulissat
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | kudahuvadhoo
# Processing Record 17 of Set 6 | gravdal
# Processing Record 18 of Set 6 | russell
# Processing Record 19 of Set 6 | richards bay
# Processing Record 20 of Set 6 | veraval
# Processing Record 21 of Set 6 | salinopolis
# Processing Record 22 of Set 6 | alyangula
# Processing Record 23 of Set 6 | beira
# Processing Record 24 of Set 6 | antofagasta
# Processing Record 25 of Set 6 | tilichiki
# Processing Record 26 of Set 6 | killybegs
# Processing Record 27 of Set 6 | aberdeen
# Processing Record 28 of Set 6 | trinidad
# Processing Record 29 of Set 6 | osmena
# Processing Record 30 of Set 6 | tessalit
# Processing Record 31 of Set 6 | elko
# Processing Record 32 of Set 6 | viesca
# Processing Record 33 of Set 6 | savinka
# Processing Record 34 of Set 6 | surt
# Processing Record 35 of Set 6 | menomonie
# Processing Record 36 of Set 6 | shelburne
# Processing Record 37 of Set 6 | tual
# Processing Record 38 of Set 6 | nyimba
# Processing Record 39 of Set 6 | beroroha
# Processing Record 40 of Set 6 | alvorada
# Processing Record 41 of Set 6 | pangai
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | languyan
# Processing Record 44 of Set 6 | bilma
# Processing Record 45 of Set 6 | ancud
# Processing Record 46 of Set 6 | myitkyina
# Processing Record 47 of Set 6 | port-gentil
# Processing Record 48 of Set 6 | tigil
# Processing Record 49 of Set 6 | iskateley
# Processing Record 50 of Set 6 | san cristobal
# Processing Record 1 of Set 7 | guerrero negro
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | cap malheureux
# Processing Record 4 of Set 7 | san lawrenz
# Processing Record 5 of Set 7 | podgornoye
# Processing Record 6 of Set 7 | soria
# Processing Record 7 of Set 7 | bonthe
# Processing Record 8 of Set 7 | pahrump
# Processing Record 9 of Set 7 | kindu
# Processing Record 10 of Set 7 | pilar
# Processing Record 11 of Set 7 | port alfred
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 7 | ambon
# Processing Record 15 of Set 7 | fairbanks
# Processing Record 16 of Set 7 | gasa
# Processing Record 17 of Set 7 | jacareacanga
# Processing Record 18 of Set 7 | singaraja
# Processing Record 19 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 7 | dir
# Processing Record 21 of Set 7 | ilmajoki
# Processing Record 22 of Set 7 | tazovskiy
# Processing Record 23 of Set 7 | batemans bay
# Processing Record 24 of Set 7 | ahaus
# Processing Record 25 of Set 7 | san diego de los banos
# Processing Record 26 of Set 7 | roma
# Processing Record 27 of Set 7 | baykit
# Processing Record 28 of Set 7 | shingu
# Processing Record 29 of Set 7 | paraje nuevo
# Processing Record 30 of Set 7 | pocoes
# Processing Record 31 of Set 7 | vysokogornyy
# Processing Record 32 of Set 7 | martapura
# Processing Record 33 of Set 7 | san jose de gracia
# Processing Record 34 of Set 7 | fort frances
# Processing Record 35 of Set 7 | orchard homes
# Processing Record 36 of Set 7 | fairview
# Processing Record 37 of Set 7 | zhurivka
# Processing Record 38 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 7 | keflavik
# Processing Record 40 of Set 7 | caravelas
# Processing Record 41 of Set 7 | ndende
# Processing Record 42 of Set 7 | mehamn
# Processing Record 43 of Set 7 | qujing
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | dingle
# Processing Record 47 of Set 7 | comodoro rivadavia
# Processing Record 48 of Set 7 | teknaf
# Processing Record 49 of Set 7 | tiarei
# Processing Record 50 of Set 7 | dubrovnik
# Processing Record 1 of Set 8 | henties bay
# Processing Record 2 of Set 8 | thompson
# Processing Record 3 of Set 8 | bonoua
# Processing Record 4 of Set 8 | yamada
# Processing Record 5 of Set 8 | tautira
# Processing Record 6 of Set 8 | milkovo
# Processing Record 7 of Set 8 | atherton
# Processing Record 8 of Set 8 | husavik
# Processing Record 9 of Set 8 | araouane
# Processing Record 10 of Set 8 | lalmohan
# Processing Record 11 of Set 8 | los arabos
# Processing Record 12 of Set 8 | tomatlan
# Processing Record 13 of Set 8 | qasigiannguit
# Processing Record 14 of Set 8 | turochak
# Processing Record 15 of Set 8 | east london
# Processing Record 16 of Set 8 | onalaska
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | bonavista
# Processing Record 19 of Set 8 | ocos
# Processing Record 20 of Set 8 | canon city
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | reconquista
# Processing Record 23 of Set 8 | witu
# Processing Record 24 of Set 8 | chhabra
# Processing Record 25 of Set 8 | bac ninh
# Processing Record 26 of Set 8 | muroto
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | tasiilaq
# Processing Record 29 of Set 8 | mugur-aksy
# Processing Record 30 of Set 8 | daru
# Processing Record 31 of Set 8 | imeni poliny osipenko
# Processing Record 32 of Set 8 | gushikawa
# Processing Record 33 of Set 8 | rio grande
# Processing Record 34 of Set 8 | bengkulu
# Processing Record 35 of Set 8 | avera
# Processing Record 36 of Set 8 | laureles
# Processing Record 37 of Set 8 | aykhal
# Processing Record 38 of Set 8 | trojan
# Processing Record 39 of Set 8 | krasnyy gulyay
# Processing Record 40 of Set 8 | skovde
# City not found. Skipping...
# Processing Record 41 of Set 8 | kang
# Processing Record 42 of Set 8 | kamaishi
# Processing Record 43 of Set 8 | kostomuksha
# Processing Record 44 of Set 8 | namalenga
# Processing Record 45 of Set 8 | kirakira
# Processing Record 46 of Set 8 | nevyansk
# Processing Record 47 of Set 8 | anadyr
# Processing Record 48 of Set 8 | kenai
# Processing Record 49 of Set 8 | heishan
# Processing Record 50 of Set 8 | nyzhni sirohozy
# Processing Record 1 of Set 9 | toba
# Processing Record 2 of Set 9 | methoni
# Processing Record 3 of Set 9 | chingirlau
# Processing Record 4 of Set 9 | dharchula
# Processing Record 5 of Set 9 | ramanuj ganj
# Processing Record 6 of Set 9 | saquena
# Processing Record 7 of Set 9 | sao mateus
# Processing Record 8 of Set 9 | sarakhs
# Processing Record 9 of Set 9 | komsomolskiy
# Processing Record 10 of Set 9 | elk point
# Processing Record 11 of Set 9 | alexandria
# Processing Record 12 of Set 9 | vardo
# Processing Record 13 of Set 9 | caraquet
# Processing Record 14 of Set 9 | sal rei
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | okhotsk
# Processing Record 17 of Set 9 | sao felix do xingu
# Processing Record 18 of Set 9 | puerto ayora
# Processing Record 19 of Set 9 | requena
# Processing Record 20 of Set 9 | priargunsk
# Processing Record 21 of Set 9 | gifhorn
# Processing Record 22 of Set 9 | brooks
# Processing Record 23 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | tete
# Processing Record 26 of Set 9 | hebertville
# City not found. Skipping...
# Processing Record 27 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 9 | carballo
# Processing Record 29 of Set 9 | ilhabela
# Processing Record 30 of Set 9 | carrigaline
# Processing Record 31 of Set 9 | luganville
# Processing Record 32 of Set 9 | khilok
# Processing Record 33 of Set 9 | nabire
# Processing Record 34 of Set 9 | pesqueria
# Processing Record 35 of Set 9 | chapais
# Processing Record 36 of Set 9 | verkhnyaya inta
# Processing Record 37 of Set 9 | laurel
# Processing Record 38 of Set 9 | hope
# Processing Record 39 of Set 9 | beringovskiy
# Processing Record 40 of Set 9 | la ronge
# Processing Record 41 of Set 9 | karasburg
# Processing Record 42 of Set 9 | qostanay
# Processing Record 43 of Set 9 | log
# Processing Record 44 of Set 9 | belyy yar
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | petropavlovka
# Processing Record 47 of Set 9 | vilyuysk
# Processing Record 48 of Set 9 | little current
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | phulabani
# Processing Record 1 of Set 10 | baltay
# Processing Record 2 of Set 10 | aripuana
# Processing Record 3 of Set 10 | gurlan
# Processing Record 4 of Set 10 | krasnyy chikoy
# Processing Record 5 of Set 10 | santiago
# Processing Record 6 of Set 10 | polis
# Processing Record 7 of Set 10 | necochea
# Processing Record 8 of Set 10 | devrek
# Processing Record 9 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 10 | faya
# Processing Record 11 of Set 10 | souillac
# Processing Record 12 of Set 10 | luwuk
# Processing Record 13 of Set 10 | morehead
# Processing Record 14 of Set 10 | havre-saint-pierre
# Processing Record 15 of Set 10 | leningradskiy
# Processing Record 16 of Set 10 | kholodnyy
# Processing Record 17 of Set 10 | atambua
# Processing Record 18 of Set 10 | armidale
# Processing Record 19 of Set 10 | viedma
# Processing Record 20 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 10 | dire
# Processing Record 23 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 24 of Set 10 | turayf
# Processing Record 25 of Set 10 | sao jose da coroa grande
# Processing Record 26 of Set 10 | ustka
# Processing Record 27 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | yuancheng
# Processing Record 29 of Set 10 | hit
# Processing Record 30 of Set 10 | ossora
# Processing Record 31 of Set 10 | lufilufi
# Processing Record 32 of Set 10 | chulym
# Processing Record 33 of Set 10 | zhovti vody
# Processing Record 34 of Set 10 | punta cardon
# Processing Record 35 of Set 10 | ventspils
# Processing Record 36 of Set 10 | sterling
# Processing Record 37 of Set 10 | beloha
# Processing Record 38 of Set 10 | camacha
# Processing Record 39 of Set 10 | aswan
# Processing Record 40 of Set 10 | vikhorevka
# Processing Record 41 of Set 10 | tateyama
# Processing Record 42 of Set 10 | alihe
# Processing Record 43 of Set 10 | ravar
# Processing Record 44 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 10 | doka
# Processing Record 46 of Set 10 | tosham
# Processing Record 47 of Set 10 | fruitville
# Processing Record 48 of Set 10 | thinadhoo
# Processing Record 49 of Set 10 | myrtle grove
# Processing Record 50 of Set 10 | monrovia
# Processing Record 1 of Set 11 | roald
# Processing Record 2 of Set 11 | kulunda
# Processing Record 3 of Set 11 | zhigansk
# Processing Record 4 of Set 11 | lorengau
# Processing Record 5 of Set 11 | plettenberg bay
# Processing Record 6 of Set 11 | pingzhuang
# Processing Record 7 of Set 11 | nara
# Processing Record 8 of Set 11 | victoria point
# Processing Record 9 of Set 11 | svirstroy
# Processing Record 10 of Set 11 | quatre cocos
# Processing Record 11 of Set 11 | saldanha
# Processing Record 12 of Set 11 | tongliao
# Processing Record 13 of Set 11 | lagunas
# Processing Record 14 of Set 11 | smithers
# Processing Record 15 of Set 11 | kanel
# Processing Record 16 of Set 11 | kelo
# Processing Record 17 of Set 11 | sept-iles
# Processing Record 18 of Set 11 | ulladulla
# Processing Record 19 of Set 11 | mapastepec
# Processing Record 20 of Set 11 | esperance
# Processing Record 21 of Set 11 | the valley
# Processing Record 22 of Set 11 | general roca
# Processing Record 23 of Set 11 | ushtobe
# Processing Record 24 of Set 11 | long beach
# Processing Record 25 of Set 11 | gamba
# Processing Record 26 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 11 | oranjemund
# Processing Record 28 of Set 11 | zalantun
# Processing Record 29 of Set 11 | ketchikan
# Processing Record 30 of Set 11 | taltal
# Processing Record 31 of Set 11 | lalibela
# Processing Record 32 of Set 11 | pacific grove
# Processing Record 33 of Set 11 | rio gallegos
# Processing Record 34 of Set 11 | beni
# Processing Record 35 of Set 11 | lompoc
# Processing Record 36 of Set 11 | lipari
# Processing Record 37 of Set 11 | merke
# Processing Record 38 of Set 11 | lazaro cardenas
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | crestview
# Processing Record 41 of Set 11 | gat
# Processing Record 42 of Set 11 | san miguelito
# Processing Record 43 of Set 11 | dubna
# Processing Record 44 of Set 11 | korla
# Processing Record 45 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 11 | ndola
# Processing Record 47 of Set 11 | cabo rojo
# Processing Record 48 of Set 11 | savannakhet
# Processing Record 49 of Set 11 | melilla
# Processing Record 50 of Set 11 | vincennes
# Processing Record 1 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 12 | hastings
# Processing Record 3 of Set 12 | tukrah
# Processing Record 4 of Set 12 | ouadda
# Processing Record 5 of Set 12 | palmeiras de goias
# Processing Record 6 of Set 12 | raudeberg
# Processing Record 7 of Set 12 | raga
# Processing Record 8 of Set 12 | mnogovershinnyy
# Processing Record 9 of Set 12 | hualmay
# Processing Record 10 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 12 | rudbar
# Processing Record 12 of Set 12 | shache
# Processing Record 13 of Set 12 | kichmengskiy gorodok
# Processing Record 14 of Set 12 | winneba
# Processing Record 15 of Set 12 | arua
# Processing Record 16 of Set 12 | chop
# Processing Record 17 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 18 of Set 12 | yerbogachen
# Processing Record 19 of Set 12 | troy
# Processing Record 20 of Set 12 | paita
# Processing Record 21 of Set 12 | adre
# Processing Record 22 of Set 12 | bud
# Processing Record 23 of Set 12 | biak
# Processing Record 24 of Set 12 | san felipe
# Processing Record 25 of Set 12 | slupsk
# Processing Record 26 of Set 12 | dosso
# Processing Record 27 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 12 | itarema
# Processing Record 29 of Set 12 | pangoa
# Processing Record 30 of Set 12 | sao joao da barra
# Processing Record 31 of Set 12 | phalodi
# Processing Record 32 of Set 12 | arroyo
# Processing Record 33 of Set 12 | ulaangom
# Processing Record 34 of Set 12 | nerchinskiy zavod
# Processing Record 35 of Set 12 | labuhan
# Processing Record 36 of Set 12 | mollendo
# Processing Record 37 of Set 12 | mende
# Processing Record 38 of Set 12 | port hedland
# Processing Record 39 of Set 12 | kodinsk
# Processing Record 40 of Set 12 | motygino
# Processing Record 41 of Set 12 | snezhnogorsk
# Processing Record 42 of Set 12 | la macarena
# Processing Record 43 of Set 12 | road town
# Processing Record 44 of Set 12 | aklavik
# Processing Record 45 of Set 12 | pasni
# Processing Record 46 of Set 12 | pontianak
# Processing Record 47 of Set 12 | yongan
# Processing Record 48 of Set 12 | rincon
# Processing Record 49 of Set 12 | ingham
# Processing Record 50 of Set 12 | bara
# Processing Record 1 of Set 13 | bundaberg
# Processing Record 2 of Set 13 | zaragoza
# Processing Record 3 of Set 13 | leshukonskoye
# Processing Record 4 of Set 13 | dwarka
# Processing Record 5 of Set 13 | carbonia
# Processing Record 6 of Set 13 | surdulica
# Processing Record 7 of Set 13 | barranca
# Processing Record 8 of Set 13 | victoria
# Processing Record 9 of Set 13 | channel-port aux basques
# Processing Record 10 of Set 13 | devils lake
# Processing Record 11 of Set 13 | hovd
# Processing Record 12 of Set 13 | jega
# Processing Record 13 of Set 13 | porto novo
# Processing Record 14 of Set 13 | tabuk
# Processing Record 15 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 13 | saint anthony
# Processing Record 17 of Set 13 | batagay
# Processing Record 18 of Set 13 | tromso
# Processing Record 19 of Set 13 | lima
# Processing Record 20 of Set 13 | ariquemes
# Processing Record 21 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 22 of Set 13 | skjervoy
# Processing Record 23 of Set 13 | praia da vitoria
# Processing Record 24 of Set 13 | sorland
# Processing Record 25 of Set 13 | nayudupeta
# Processing Record 26 of Set 13 | abashiri
# Processing Record 27 of Set 13 | corum
# Processing Record 28 of Set 13 | atasu
# Processing Record 29 of Set 13 | warner robins
# Processing Record 30 of Set 13 | xuddur
# Processing Record 31 of Set 13 | san policarpo
# Processing Record 32 of Set 13 | bowen
# Processing Record 33 of Set 13 | vizinga
# Processing Record 34 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 13 | half moon bay
# Processing Record 36 of Set 13 | babu
# Processing Record 37 of Set 13 | strezhevoy
# Processing Record 38 of Set 13 | hirara
# Processing Record 39 of Set 13 | pouembout
# Processing Record 40 of Set 13 | inhambane
# Processing Record 41 of Set 13 | taman
# Processing Record 42 of Set 13 | strelka
# Processing Record 43 of Set 13 | huangnihe
# Processing Record 44 of Set 13 | mananjary
# Processing Record 45 of Set 13 | maraa
# Processing Record 46 of Set 13 | yar-sale
# Processing Record 47 of Set 13 | benghazi
# Processing Record 48 of Set 13 | sandnessjoen
# Processing Record 49 of Set 13 | novopavlovka
# Processing Record 50 of Set 13 | darhan
# Processing Record 1 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 14 | barra da estiva
# Processing Record 3 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 14 | eldorado
# Processing Record 5 of Set 14 | ostrovnoy
# Processing Record 6 of Set 14 | lyuban
# Processing Record 7 of Set 14 | portland
# Processing Record 8 of Set 14 | cassilandia
# Processing Record 9 of Set 14 | camara de lobos
# Processing Record 10 of Set 14 | dinguiraye
# Processing Record 11 of Set 14 | bauchi
# Processing Record 12 of Set 14 | devonport
# Processing Record 13 of Set 14 | almaznyy
# Processing Record 14 of Set 14 | lata
# Processing Record 15 of Set 14 | muros
# Processing Record 16 of Set 14 | maceio
# Processing Record 17 of Set 14 | north bend
# Processing Record 18 of Set 14 | finschhafen
# Processing Record 19 of Set 14 | brigantine
# Processing Record 20 of Set 14 | brae
# Processing Record 21 of Set 14 | arman
# Processing Record 22 of Set 14 | port hawkesbury
# Processing Record 23 of Set 14 | dickinson
# Processing Record 24 of Set 14 | xinzhou
# Processing Record 25 of Set 14 | minsk
# Processing Record 26 of Set 14 | namatanai
# Processing Record 27 of Set 14 | nemuro
# Processing Record 28 of Set 14 | port shepstone
# Processing Record 29 of Set 14 | akcakoca
# Processing Record 30 of Set 14 | aksarka
# Processing Record 31 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 14 | aleppo
# Processing Record 33 of Set 14 | soverato
# Processing Record 34 of Set 14 | nelson bay
# Processing Record 35 of Set 14 | springbok
# Processing Record 36 of Set 14 | flinders
# Processing Record 37 of Set 14 | mangai
# Processing Record 38 of Set 14 | terme
# Processing Record 39 of Set 14 | mamit
# Processing Record 40 of Set 14 | birnin kebbi
# Processing Record 41 of Set 14 | lauingen
# Processing Record 42 of Set 14 | agva
# City not found. Skipping...
# Processing Record 43 of Set 14 | ambilobe
# Processing Record 44 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 14 | westerland
# Processing Record 46 of Set 14 | ko samui
# Processing Record 47 of Set 14 | oistins
# Processing Record 48 of Set 14 | una
# Processing Record 49 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 14 | ciparay
# Processing Record 1 of Set 15 | binga
# Processing Record 2 of Set 15 | laguna
# Processing Record 3 of Set 15 | tigzirt
# Processing Record 4 of Set 15 | aldan
# Processing Record 5 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 15 | sabang
# Processing Record 7 of Set 15 | zelenoborskiy
# Processing Record 8 of Set 15 | skala fourkas
# Processing Record 9 of Set 15 | merauke
# Processing Record 10 of Set 15 | mamanguape
# Processing Record 11 of Set 15 | panyutyne
# Processing Record 12 of Set 15 | orasac
# Processing Record 13 of Set 15 | bosaso
# Processing Record 14 of Set 15 | adrar
# Processing Record 15 of Set 15 | brenham
# Processing Record 16 of Set 15 | edson
# Processing Record 17 of Set 15 | san quintin
# Processing Record 18 of Set 15 | kavaratti
# Processing Record 19 of Set 15 | okha
# Processing Record 20 of Set 15 | zhangye
# Processing Record 21 of Set 15 | cape elizabeth
# City not found. Skipping...
# Processing Record 22 of Set 15 | makakilo city
# Processing Record 23 of Set 15 | kulhudhuffushi
# Processing Record 24 of Set 15 | ghauspur
# Processing Record 25 of Set 15 | masaka
# Processing Record 26 of Set 15 | bihac
# Processing Record 27 of Set 15 | wanning
# Processing Record 28 of Set 15 | nongstoin
# Processing Record 29 of Set 15 | palauig
# Processing Record 30 of Set 15 | beyneu
# Processing Record 31 of Set 15 | bulgan
# Processing Record 32 of Set 15 | mayo
# Processing Record 33 of Set 15 | tambacounda
# Processing Record 34 of Set 15 | nakambala
# Processing Record 35 of Set 15 | mugumu
# Processing Record 36 of Set 15 | najran
# Processing Record 37 of Set 15 | zhanaozen
# Processing Record 38 of Set 15 | ahipara
# Processing Record 39 of Set 15 | belaya gora
# Processing Record 40 of Set 15 | tongzi
# Processing Record 41 of Set 15 | popondetta
# Processing Record 42 of Set 15 | yokadouma
# Processing Record 43 of Set 15 | waipawa
# Processing Record 44 of Set 15 | alpoyeca
# Processing Record 45 of Set 15 | aracatuba
# Processing Record 46 of Set 15 | gubkinskiy
# Processing Record 47 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 15 | sicamous
# Processing Record 49 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 15 | teguise
# Processing Record 1 of Set 16 | french harbor
# Processing Record 2 of Set 16 | bubaque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hobyo      SO   5.3505   48.5268     79.02        70           8
# 1        Naze      JP  28.3667  129.4833     70.72        75         100
# 2     Ushuaia      AR -54.8000  -68.3000     37.06        81          90
# 3     Ducheng      CN  23.2373  111.5317     67.89        96          31
# 4   Cape Town      ZA -33.9258   18.4232     67.12        62           0
# 5     Rikitea      PF -23.1203 -134.9692     73.54        61          50
# 6      Orocue      CO   4.7912  -71.3354     84.04        63          99
# 7    Hamilton      US  39.1834  -84.5333     51.94        52          90
# 8   Busselton      AU -33.6500  115.3333     57.04        61          70
# 9  Chokurdakh      RU  70.6333  147.9167    -14.53       100          85
#
#    Wind Speed Current Description
# 0       10.94           clear sky
# 1       13.67     overcast clouds
# 2       23.02          heavy snow
# 3        2.37    scattered clouds
# 4       12.66           clear sky
# 5        5.17    scattered clouds
# 6        5.84     overcast clouds
# 7        1.01     overcast clouds
# 8       10.85       broken clouds
# 9        6.02     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
